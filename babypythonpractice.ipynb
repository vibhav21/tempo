# %%
alists=[1,2,3,4,5]
asquaredlist=[i*i for i in alists]
print(asquaredlist)
# Out:
# [1, 4, 9, 16, 25]

# %%
for x,y in enumerate(asquaredlist):
    print(f"({x},{y})",end=" ")
# Out:
# (0,1) (1,4) (2,9) (3,16) (4,25)

# %%
for x,y in zip(alists,asquaredlist):
    print(f"({x},{y})")
# Out:
# (1,1)
# (2,4)
# (3,9)
# (4,16)
# (5,25)

# %%
linelengths=[len(line) for line in open("hamlet.txt")]
print(linelengths)
# Out:
# [6, 26, 1, 23, 1, 1, 1, 1, 21, 1, 27, 59, 28, 27, 26, 21, 21, 23, 24, 17, 23, 10, 20, 19, 21, 31, 9, 27, 30, 11, 21, 26, 1, 50, 31, 1, 66, 12, 1, 17, 1, 1, 1, 7, 1, 49, 1, 48, 1, 5, 13, 1, 6, 44, 1, 5, 20, 1, 6, 10, 1, 5, 4, 1, 6, 40, 1, 5, 52, 1, 6, 47, 24, 1, 5, 26, 1, 6, 22, 1, 5, 18, 38, 45, 1, 6, 47, 1, 31, 1, 5, 24, 1, 5, 26, 1, 6, 21, 1, 5, 29, 23, 1, 6, 23, 21, 1, 8, 1, 5, 17, 1, 5, 5, 24, 1, 5, 16, 1, 5, 44, 1, 5, 46, 1, 5, 21, 1, 5, 35, 41, 47, 37, 44, 36, 41, 1, 5, 31, 1, 5, 17, 40, 41, 30, 1, 5, 19, 40, 1, 5, 19, 50, 50, 42, 29, 1, 5, 50, 1, 22, 1, 5, 47, 1, 5, 42, 1, 5, 46, 1, 5, 48, 1, 5, 22, 1, 5, 22, 1, 5, 49, 41, 39, 53, 1, 5, 16, 1, 5, 21, 1, 5, 41, 1, 14, 1, 5, 32, 1, 5, 45, 41, 21, 1, 5, 40, 37, 18, 1, 5, 25, 1, 5, 24, 35, 39, 44, 41, 14, 1, 5, 47, 46, 1, 5, 47, 43, 47, 1, 5, 48, 46, 42, 42, 40, 49, 42, 45, 49, 29, 1, 5, 12, 46, 41, 43, 44, 52, 52, 52, 35, 49, 44, 38, 42, 34, 49, 38, 48, 35, 46, 40, 38, 47, 41, 38, 45, 44, 40, 49, 43, 1, 5, 36, 46, 48, 44, 1, 5, 4
# ...

# %%
import numpy as np

# %%
sum(linelengths),np.mean(linelengths),np.median(linelengths)
# Out:
# (173946, 25.69364844903988, 25.0)

# %%
hamletfile=open("hamlet.txt")
hamlettext=hamletfile.read()
hamletfile.close()
hamlettokens=hamlettext.split()
print(len(hamlettokens))
#hamlettokens=set(hamlettokens)
h=set(hamlettokens)
print(len(h))
# Out:
# 31659
# 7967

# %%
with open("hamlet.txt") as hamletfile:
    hamlettext=hamletfile.read()
    hamlettokens=hamlettext.split()
    print(len(hamlettokens))
# Out:
# 31659

# %%
mydict ={k:v for k,v in zip(alists, asquaredlist)}
print(mydict)
import json
s=json.dumps(mydict)
print(s)
print(json.loads(s))
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {"1": 1, "2": 4, "3": 9, "4": 16, "5": 25}
# {'1': 1, '2': 4, '3': 9, '4': 16, '5': 25}

# %%
wierdstring=" ".join(hamlettokens)# joining elements of a list
wierdstring[:1000]
# Out:
# "\ufeffXXXXHAMLET,PRINCEOFDENMARKbyWilliamShakespearePERSONSREPRESENTED.Claudius,KingofDenmark.Hamlet,Sontotheformer,andNephewtothepresentKing.Polonius,LordChamberlain.Horatio,FriendtoHamlet.Laertes,SontoPolonius.Voltimand,Courtier.Cornelius,Courtier.Rosencrantz,Courtier.Guildenstern,Courtier.Osric,Courtier.AGentleman,Courtier.APriest.Marcellus,Officer.Bernardo,Officer.Francisco,aSoldierReynaldo,ServanttoPolonius.Players.TwoClowns,Grave-diggers.Fortinbras,PrinceofNorway.ACaptain.EnglishAmbassadors.GhostofHamlet'sFather.Gertrude,QueenofDenmark,andMotherofHamlet.Ophelia,DaughtertoPolonius.Lords,Ladies,Officers,Soldiers,Sailors,Messengers,andotherAttendants.SCENE.Elsinore.ACTI.SceneI.Elsinore.AplatformbeforetheCastle.[Franciscoathispost.EntertohimBernardo.]Ber.Who'sthere?Fran.Nay,answerme:stand,andunfoldyourself.Ber.Longlivetheking!Fran.Bernardo?Ber.He.Fran.Youcomemostcarefullyuponyourhour.Ber.'Tisnowstrucktwelve.Gettheetobed,Francisco.Fran.Forthisreliefmuchthanks:'tisbittercold,AndIams
# ...

# %%
def square(x):
    return x*x;
    
def sumOfAnything(x,y,f):
    print(x,y)
    print(f(x)+f(y))
sumOfAnything(3,4,square)
# Out:
# 3 4
# 25

# %%
def f(a,b,*args):
    print("got",args)
f(1,3)    
f(1,2,3,4,5,5)
# Out:
# got ()
# got (3, 4, 5, 5)

# %%
try:
    f(1)
except:
    print("there is an exception")
# Out:
# there is an exception

# %%
hamletctokens=[word.lower() for word in hamlettokens]
hamletctokens.count("thou")
# Out:
# 95

# %%
uniquectokens=set(hamletctokens)
len(uniquectokens)
# Out:
# 7456

# %% [raw]
# tokendict={}
# for ut in uniquectokens:
#     tokendict[ut]=hamletctokens.count(ut)
# tokendict

# %%
L=sorted(tokendict.items(),reverse=True)[:100]
L
# Out:
# [('\ufeffxxxx', 1),
#  ('zone,', 1),
#  ('youth:', 1),
#  ('youth,', 3),
#  ('youth', 12),
#  ('yourselves', 1),
#  ('yourself:', 1),
#  ('yourself.', 3),
#  ('yourself,', 3),
#  ('yourself', 7),
#  ('yours:', 1),
#  ('yours.', 2),
#  ('yours,', 2),
#  ('yours', 1),
#  ('your', 241),
#  ('younger', 1),
#  ('young;', 1),
#  ('young', 16),
#  ('you?', 13),
#  ('you;--though,', 1),
#  ('you;', 9),
#  ('you:--why', 1),
#  ('you:--keep', 1),
#  ('you:--', 2),
#  ('you:', 12),
#  ('you.--if', 1),
#  ('you.--good', 1),
#  ('you.--for', 1),
#  ('you.', 22),
#  ('you,--', 2),
#  ('you,', 66),
#  ("you're", 1),
#  ("you'll", 3),
#  ('you!', 1),
#  ('you', 412),
#  ("yorick's", 1),
#  ('yorick!--i', 1),
#  ('yonder', 2),
#  ('yond', 1),
#  ('yon', 1),
#  ('yielding', 1),
#  ('yield', 2),
#  ('yet?', 1),
#  ('yet,', 5),
#  ('yet', 35),
#  ('yesty', 1),
#  ('yesternight.', 1),
#  ('yesterday,', 1),
#  ('yes,', 5),
#  ("yeoman's", 1),
#  ('years.', 2),
#  ('years', 1),
#  ('year:', 2),
# ...

# %%
L=sorted(tokendict.items(), key= lambda k:k[1], reverse=True)[:100]
L
# Out:
# [('the', 1136),
#  ('and', 943),
#  ('to', 720),
#  ('of', 667),
#  ('a', 527),
#  ('my', 512),
#  ('i', 510),
#  ('in', 420),
#  ('you', 412),
#  ('ham.', 358),
#  ('that', 337),
#  ('it', 324),
#  ('is', 320),
#  ('his', 295),
#  ('not', 270),
#  ('with', 264),
#  ('this', 250),
#  ('your', 241),
#  ('for', 231),
#  ('but', 228),
#  ('as', 216),
#  ('he', 202),
#  ('be', 201),
#  ('what', 183),
#  ('have', 174),
#  ('will', 149),
#  ('so', 143),
#  ('me', 142),
#  ('we', 132),
#  ('do', 128),
#  ('are', 126),
#  ('him', 122),
#  ('our', 119),
#  ('king.', 113),
#  ('by', 111),
#  ('hor.', 110),
#  ('if', 109),
#  ('on', 109),
#  ('or', 109),
#  ('no', 107),
#  ('shall', 106),
#  ('thou', 95),
#  ('from', 95),
#  ('all', 95),
#  ('they', 93),
#  ('let', 92),
#  ('good', 88),
#  ('thy', 86),
#  ('pol.', 86),
#  ('at', 86),
#  ('how', 84),
#  ('most', 82),
#  ('lord,', 81),
#  ('more', 76),
#  ('her', 76),
#  ('queen.', 76),
#  ('like', 75),
#  ('would', 74),
#  ('was', 73),
# ...
